# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
timetest = pd.read_csv("timetest.txt")

# %%
timetest.head()
# Out:
#        time
# 0  0.109943
# 1  0.124923
# 2  0.122730
# 3  0.123572
# 4  0.123890

# %%
timetest['time'] = 1000*timetest['time']

# %%
timetest.hist(column='time', bins=10, grid=False, figsize=(12,8), color='#86bf91', zorder=4, rwidth=0.9)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002389AE678C8>]],
#       dtype=object)

# %%
acctest = pd.read_csv("acctest.txt")
acctest.head()
# Out:
#       reward   len
# 0  607.05150  1882
# 1  281.95630   140
# 2  400.45483   417
# 3  363.37515   199
# 4  349.26627   279

# %%
acctest.hist(column='reward', bins=10, grid=False, figsize=(12,8), color='#66badf', zorder=4, rwidth=0.9)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002389BDD9108>]],
#       dtype=object)

# %%
acctest.hist(column='len', bins=10, grid=False, figsize=(12,8), color='#FF9176', zorder=4, rwidth=0.9)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002389C986108>]],
#       dtype=object)
